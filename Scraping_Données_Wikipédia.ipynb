# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import bs4
import numpy as np

url='https://fr.wikipedia.org/wiki/%C3%89volution_d%C3%A9taill%C3%A9e_des_accidents_routiers_en_France_m%C3%A9tropolitaine'
r = requests.get(url)
print(r.status_code)
# Out:
# 200

# %%
df=pd.read_html(r.content)
df1 = df[0]
df1.head(100)
# Out:
#    Année[2] Accidents                                       Tués à 3 jours  \
#    Année[2]    Nombre Évolution(en %) dontaccidents mortels         Nombre
# 0      1948       NaN             NaN                   NaN            NaN
# 1      1949    25 247             NaN                   NaN          2 878
# 2      1950    50 000             NaN                   NaN          4 000
# 3      1951    70 000             NaN                   NaN          4 500
# 4      1952    95 000             NaN                   NaN          5 800
# 5      1953   118 881             ---                   ---          7 166
# 6      1954   124 970           + 5,1                   ---          7 539
# 7      1955   140 232          + 12,2                 7 554          8 058
# 8      1956   141 737           + 1,1                 7 740          8 283
# 9      1957   143 796           + 1,4                 8 055          8 517
# ...

# %%
df1.info()
#df.set_index('Année[2]', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   (Année[2], Année[2])                         20 non-null     int64
#  1   (Accidents, Nombre)                          19 non-null     object
#  2   (Accidents, Évolution(en %))                 15 non-null     object
#  3   (Accidents, dontaccidents mortels)           15 non-null     object
#  4   (Tués à 3 jours, Nombre)                     19 non-null     object
#  5   (Tués à 3 jours, Évolution(en %))            15 non-null     object
#  6   (Blessés graves, Blessés graves)             15 non-null     object
#  7   (Blessés légers, Blessés légers)             15 non-null     object
#  8   (Total blessés, Nombre)                      19 non-null     object
# ...

# %%
df1 = df1.drop(df1.columns[[11]], axis=1)
df1.head(100)
# Out:
#    Année[2] Accidents                                       Tués à 3 jours  \
#    Année[2]    Nombre Évolution(en %) dontaccidents mortels         Nombre
# 0      1948       NaN             NaN                   NaN            NaN
# 1      1949    25 247             NaN                   NaN          2 878
# 2      1950    50 000             NaN                   NaN          4 000
# 3      1951    70 000             NaN                   NaN          4 500
# 4      1952    95 000             NaN                   NaN          5 800
# 5      1953   118 881             ---                   ---          7 166
# 6      1954   124 970           + 5,1                   ---          7 539
# 7      1955   140 232          + 12,2                 7 554          8 058
# 8      1956   141 737           + 1,1                 7 740          8 283
# 9      1957   143 796           + 1,4                 8 055          8 517
# ...

# %%
#df = df.drop_duplicates(subset=['Année[2]'])
#df
#df["Année[2]"] = df["Année[2]"].astype(object)
print (df1.shape[1])
# Out:
# 11

# %%
print (range(df1.shape[1]))
# Out:
# range(0, 11)

# %%
df1.columns = range(df1.shape[1])
print(df1)
# Out:
#        0        1       2       3       4       5       6        7        8  \
# 0   1948      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 1   1949   25 247     NaN     NaN   2 878     NaN     NaN      NaN   22 000
# 2   1950   50 000     NaN     NaN   4 000     NaN     NaN      NaN   50 000
# 3   1951   70 000     NaN     NaN   4 500     NaN     NaN      NaN   75 000
# 4   1952   95 000     NaN     NaN   5 800     NaN     NaN      NaN  100 000
# 5   1953  118 881     ---     ---   7 166     ---     ---      ---  147 551
# 6   1954  124 970   + 5,1     ---   7 539   + 5,2  46 470  107 924  154 394
# 7   1955  140 232  + 12,2   7 554   8 058   + 6,9  56 798  119 531  176 329
# 8   1956  141 737   + 1,1   7 740   8 283   + 2,8  54 255  126 359  180 614
# 9   1957  143 796   + 1,4   8 055   8 517   + 2,8  67 650  116 100  183 750
# 10  1958  134 713   - 6,3   7 520   8 126   - 4,6  64 782  111 248  176 030
# ...

# %%
df1.head(100)
# Out:
#        0        1       2       3       4       5       6        7        8  \
# 0   1948      NaN     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 1   1949   25 247     NaN     NaN   2 878     NaN     NaN      NaN   22 000
# 2   1950   50 000     NaN     NaN   4 000     NaN     NaN      NaN   50 000
# 3   1951   70 000     NaN     NaN   4 500     NaN     NaN      NaN   75 000
# 4   1952   95 000     NaN     NaN   5 800     NaN     NaN      NaN  100 000
# 5   1953  118 881     ---     ---   7 166     ---     ---      ---  147 551
# 6   1954  124 970   + 5,1     ---   7 539   + 5,2  46 470  107 924  154 394
# 7   1955  140 232  + 12,2   7 554   8 058   + 6,9  56 798  119 531  176 329
# 8   1956  141 737   + 1,1   7 740   8 283   + 2,8  54 255  126 359  180 614
# 9   1957  143 796   + 1,4   8 055   8 517   + 2,8  67 650  116 100  183 750
# 10  1958  134 713   - 6,3   7 520   8 126   - 4,6  64 782  111 248  176 030
# ...

# %%
df1 = df1.drop([df1.index[0], df1.index[1],df1.index[2],df1.index[3],df1.index[4],df1.index[5],df1.index[6]])
df1.head(100)
# Out:
#        0        1       2       3       4       5       6        7        8  \
# 7   1955  140 232  + 12,2   7 554   8 058   + 6,9  56 798  119 531  176 329
# 8   1956  141 737   + 1,1   7 740   8 283   + 2,8  54 255  126 359  180 614
# 9   1957  143 796   + 1,4   8 055   8 517   + 2,8  67 650  116 100  183 750
# 10  1958  134 713   - 6,3   7 520   8 126   - 4,6  64 782  111 248  176 030
# 11  1959  137 273   + 1,9   7 847   8 409   + 2,8  65 154  113 639  178 793
# 12  1960  141 309   + 2,9   7 698   8 295   - 1,3  65 780  119 251  185 031
# 13  1961  159 535  + 12,9   8 423   9 140  + 10,1  69 252  144 252  213 504
# 14  1962  169 204   + 6,1   9 076   9 928   + 8,6  74 963  154 359  229 322
# 15  1963  176 275   + 4,2   9 167  10 027   + 1,0  78 399  162 555  240 954
# 16  1964  192 999   + 9,5  10 055  11 105  + 10,8  83 210  180 865  264 075
# 17  1965  210 754   + 9,2  11 021  12 150   + 9,4  90 136  200 120  290 256
# ...

# %%
df1.columns = ['Année','Nombre des accidents','évolution en %','dont accidents mortels','Nombre','Évolution en %','Blessés graves','Blessés légers','Nombre des blessés','Évolution des blessés en %','Tués pour 100 accidents corporels']
#col_index="Année"
df1=df1.set_index('Année')
df1.head(100)
# Out:
#       Nombre des accidents évolution en % dont accidents mortels  Nombre  \
# Année
# 1955               140 232         + 12,2                  7 554   8 058
# 1956               141 737          + 1,1                  7 740   8 283
# 1957               143 796          + 1,4                  8 055   8 517
# 1958               134 713          - 6,3                  7 520   8 126
# 1959               137 273          + 1,9                  7 847   8 409
# 1960               141 309          + 2,9                  7 698   8 295
# 1961               159 535         + 12,9                  8 423   9 140
# 1962               169 204          + 6,1                  9 076   9 928
# 1963               176 275          + 4,2                  9 167  10 027
# 1964               192 999          + 9,5                 10 055  11 105
# 1965               210 754          + 9,2                 11 021  12 150
# 1966               209 906          - 0,5                 10 926  12 158
# ...

# %%
df1.isnull()
# Out:
#        Nombre des accidents  évolution en %  dont accidents mortels  Nombre  \
# Année
# 1955                  False           False                   False   False
# 1956                  False           False                   False   False
# 1957                  False           False                   False   False
# 1958                  False           False                   False   False
# 1959                  False           False                   False   False
# 1960                  False           False                   False   False
# 1961                  False           False                   False   False
# 1962                  False           False                   False   False
# 1963                  False           False                   False   False
# 1964                  False           False                   False   False
# 1965                  False           False                   False   False
# ...

# %%
df[1].head()

#df[0].set_index('Année[2]', inplace=True)
# Out:
#   Année[2] Accidents                                       Tués à 6 jours  \
#   Année[2]    Nombre Évolution(en %) dontaccidents mortels         Nombre
# 0     1967   215 470             ---                12 225         13 585
# 1     1968   220 201           + 2,2                12 717         14 274
# 2     1969   220 618           + 0,2                13 028         14 664
# 3     1970   228 050           + 3,4                13 437         15 034
# 4     1971   242 464           + 6,3                14 265         16 061
#
#                   Blessés graves Blessés légers Total blessés                  \
#   Évolution(en %) Blessés graves Blessés légers        Nombre Évolution(en %)
# 0             ---         87 876        213 480       301 356             ---
# 1           + 5,1         92 020        220 293       312 313           + 3,6
# 2           + 2,7         93 882        217 391       311 273           - 0,3
# ...

# %%
df2 = df[1]
df2
# Out:
#         Année[2]     Accidents  \
#         Année[2]        Nombre
# 0           1967       215 470
# 1           1968       220 201
# 2           1969       220 618
# 3           1970       228 050
# 4           1971       242 464
# 5           1972       259 954
# 6           1973       261 212
# 7           1974       251 378
# 8           1975       251 192
# 9           1976       253 318
# 10          1977       250 158
# 11          1978       238 815
# 12          1979       242 975
# 13          1980       241 049
# 14  1981 et 1982  1981 et 1982
# 15          1983       209 715
# 16          1984       199 454
# 17          1985       191 096
# 18          1986       184 615
# 19          1987       170 994
# 20          1988       175 887
# 21          1989       170 590
# 22          1990       162 573
# 23          1991       148 890
# 24          1992       143 362
# 25          1993       137 500
# 26          1994       132 726
# 27          1995       132 949
# ...

# %%
df2 = df2.drop(df2.columns[[11]], axis=1)
df2.head()
# Out:
#   Année[2] Accidents                                       Tués à 6 jours  \
#   Année[2]    Nombre Évolution(en %) dontaccidents mortels         Nombre
# 0     1967   215 470             ---                12 225         13 585
# 1     1968   220 201           + 2,2                12 717         14 274
# 2     1969   220 618           + 0,2                13 028         14 664
# 3     1970   228 050           + 3,4                13 437         15 034
# 4     1971   242 464           + 6,3                14 265         16 061
#
#                   Blessés graves Blessés légers Total blessés                  \
#   Évolution(en %) Blessés graves Blessés légers        Nombre Évolution(en %)
# 0             ---         87 876        213 480       301 356             ---
# 1           + 5,1         92 020        220 293       312 313           + 3,6
# 2           + 2,7         93 882        217 391       311 273           - 0,3
# ...

# %%
print (df2.shape[1])
# Out:
# 12

# %%
print (range(df2.shape[1]))
# Out:
# range(0, 12)

# %%
df2.columns = range(df2.shape[1])
print(df2)
# Out:
#                0             1  \
# 0           1967       215 470
# 1           1968       220 201
# 2           1969       220 618
# 3           1970       228 050
# 4           1971       242 464
# 5           1972       259 954
# 6           1973       261 212
# 7           1974       251 378
# 8           1975       251 192
# 9           1976       253 318
# 10          1977       250 158
# 11          1978       238 815
# 12          1979       242 975
# 13          1980       241 049
# 14  1981 et 1982  1981 et 1982
# 15          1983       209 715
# 16          1984       199 454
# 17          1985       191 096
# 18          1986       184 615
# 19          1987       170 994
# 20          1988       175 887
# 21          1989       170 590
# 22          1990       162 573
# 23          1991       148 890
# 24          1992       143 362
# 25          1993       137 500
# 26          1994       132 726
# 27          1995       132 949
# 28          1996       125 406
# ...

# %%
df2 = df2.drop([df2.index[14], df2.index[0]])
df2.head(100)
# Out:
#        0        1       2       3       4       5        6        7        8  \
# 1   1968  220 201   + 2,2  12 717  14 274   + 5,1   92 020  220 293  312 313
# 2   1969  220 618   + 0,2  13 028  14 664   + 2,7   93 882  217 391  311 273
# 3   1970  228 050   + 3,4  13 437  15 034   + 2,5   96 399  224 967  321 366
# 4   1971  242 464   + 6,3  14 265  16 061   + 6,8  102 954  242 509  345 463
# 5   1972  259 954   + 7,2  14 535  16 545   + 3,0  107 445  280 918  388 363
# 6   1973  261 212   + 0,5  13 546  15 469   - 6,5   99 798  266 512  366 310
# 7   1974  251 378   - 3,8  11 905  13 327  - 13,8   92 023  252 297  344 320
# 8   1975  251 192   - 0,1  11 631  12 996   - 2,5   92 725  253 001  345 726
# 9   1976  253 318   + 0,8  12 115  13 577   + 4,5   91 539  256 206  347 745
# 10  1977  250 158   - 1,2  11 489  12 961   - 4,5   92 246  253 854  346 100
# 11  1978  238 815   - 5,5  10 670  11 957   - 7,7   86 927  240 813  327 740
# ...

# %%
df2.head()
# Out:
#       0        1      2       3       4      5        6        7        8  \
# 1  1968  220 201  + 2,2  12 717  14 274  + 5,1   92 020  220 293  312 313
# 2  1969  220 618  + 0,2  13 028  14 664  + 2,7   93 882  217 391  311 273
# 3  1970  228 050  + 3,4  13 437  15 034  + 2,5   96 399  224 967  321 366
# 4  1971  242 464  + 6,3  14 265  16 061  + 6,8  102 954  242 509  345 463
# 5  1972  259 954  + 7,2  14 535  16 545  + 3,0  107 445  280 918  388 363
#
#         9   10      11
# 1   + 3,6  648     NaN
# 2   - 0,3  665     NaN
# 3   + 3,2  659     NaN
# 4   + 7,5  662     NaN
# 5  + 12,4  636  18 034

# %%
df2.columns = ['Année','Nombre des accidents','évolution en %','dont accidents mortels','Nombre','Évolution en %','Blessés graves','Blessés légers','Nombre des blessés','Évolution des blessés en %','Tués pour 100 accidents corporels','Nombre tués à 30 jours']
#col_index="Année"
df2=df2.set_index('Année')
df2.head(100)
# Out:
#       Nombre des accidents évolution en % dont accidents mortels  Nombre  \
# Année
# 1968               220 201          + 2,2                 12 717  14 274
# 1969               220 618          + 0,2                 13 028  14 664
# 1970               228 050          + 3,4                 13 437  15 034
# 1971               242 464          + 6,3                 14 265  16 061
# 1972               259 954          + 7,2                 14 535  16 545
# 1973               261 212          + 0,5                 13 546  15 469
# 1974               251 378          - 3,8                 11 905  13 327
# 1975               251 192          - 0,1                 11 631  12 996
# 1976               253 318          + 0,8                 12 115  13 577
# 1977               250 158          - 1,2                 11 489  12 961
# 1978               238 815          - 5,5                 10 670  11 957
# 1979               242 975          + 1,7                 10 880  12 197
# ...

# %%
df2.drop('Nombre tués à 30 jours', axis=1, inplace=True)
df2.head()
# Out:
#       Nombre des accidents évolution en % dont accidents mortels  Nombre  \
# Année
# 1968               220 201          + 2,2                 12 717  14 274
# 1969               220 618          + 0,2                 13 028  14 664
# 1970               228 050          + 3,4                 13 437  15 034
# 1971               242 464          + 6,3                 14 265  16 061
# 1972               259 954          + 7,2                 14 535  16 545
#
#       Évolution en % Blessés graves Blessés légers Nombre des blessés  \
# Année
# 1968           + 5,1         92 020        220 293            312 313
# 1969           + 2,7         93 882        217 391            311 273
# 1970           + 2,5         96 399        224 967            321 366
# 1971           + 6,8        102 954        242 509            345 463
# 1972           + 3,0        107 445        280 918            388 363
#
#       Évolution des blessés en % Tués pour 100 accidents corporels
# Année
# ...

# %%
df2.isnull()
# Out:
#        Nombre des accidents  évolution en %  dont accidents mortels  Nombre  \
# Année
# 1968                  False           False                   False   False
# 1969                  False           False                   False   False
# 1970                  False           False                   False   False
# 1971                  False           False                   False   False
# 1972                  False           False                   False   False
# 1973                  False           False                   False   False
# 1974                  False           False                   False   False
# 1975                  False           False                   False   False
# 1976                  False           False                   False   False
# 1977                  False           False                   False   False
# 1978                  False           False                   False   False
# ...

# %%
df3 = df[2]
df3.head(100)
# Out:
#    Année[2] Accidents                                       Tués à 30 jours  \
#    Année[2]    Nombre Évolution(en %) dontaccidents mortels          Nombre
# 0      2005    84 525           - 1,0                 4 857           5 318
# 1      2006    80 309           - 5,0                 4 326           4 709
# 2      2007    81 272           + 1,2                 4 265           4 620
# 3      2008    74 487           - 8,3                 3 933           4 275
# 4      2009    72 315           - 2,9                 3 956           4 273
# 5      2010    67 288           - 7,0                 3 706           3 992
# 6      2011    65 024           - 3,4                 3 647           3 963
# 7      2012    60 437           - 6,9                 3 386           3 653
# 8      2013    56 812           - 6,0                 3 020           3 268
# 9      2014    58 191           + 2,4                 3 146           3 384
# ...

# %%
df3 = df3.drop(df3.columns[[11]], axis=1)
df3.head(100)
# Out:
#    Année[2] Accidents                                       Tués à 30 jours  \
#    Année[2]    Nombre Évolution(en %) dontaccidents mortels          Nombre
# 0      2005    84 525           - 1,0                 4 857           5 318
# 1      2006    80 309           - 5,0                 4 326           4 709
# 2      2007    81 272           + 1,2                 4 265           4 620
# 3      2008    74 487           - 8,3                 3 933           4 275
# 4      2009    72 315           - 2,9                 3 956           4 273
# 5      2010    67 288           - 7,0                 3 706           3 992
# 6      2011    65 024           - 3,4                 3 647           3 963
# 7      2012    60 437           - 6,9                 3 386           3 653
# 8      2013    56 812           - 6,0                 3 020           3 268
# 9      2014    58 191           + 2,4                 3 146           3 384
# ...

# %%
print (df3.shape[1])
# Out:
# 11

# %%
print (range(df3.shape[1]))
# Out:
# range(0, 11)

# %%
df3.columns = range(df3.shape[1])
print(df3)
# Out:
#           0       1       2      3      4       5       6       7        8  \
# 0      2005  84 525   - 1,0  4 857  5 318   - 4,9  39 811  68 265  108 076
# 1      2006  80 309   - 5,0  4 326  4 709     -15  40 662  61 463  102 125
# 2      2007  81 272   + 1,2  4 265  4 620   - 2,0  38 615  64 586  103 201
# 3      2008  74 487   - 8,3  3 933  4 275   - 7,5  36 179  58 833   93 798
# 4      2009  72 315   - 2,9  3 956  4 273   - 0,1  34 506  57 611   90 934
# 5      2010  67 288   - 7,0  3 706  3 992   - 6,6  30 393  54 068   84 461
# 6      2011  65 024   - 3,4  3 647  3 963   - 0,7  29 679  51 572   81 251
# 7      2012  60 437   - 6,9  3 386  3 653   - 8,0  27 142  48 709   75 851
# 8      2013  56 812   - 6,0  3 020  3 268  - 10,5  25 966  44 641   70 607
# 9      2014  58 191   + 2,4  3 146  3 384   + 3,5  26 635  46 413   73 048
# 10     2015  56 603   - 2,7  3 160  3 461   + 2,3  26 595  44 207   70 802
# ...

# %%
df3.head(50)
# Out:
#           0       1       2      3      4       5       6       7        8  \
# 0      2005  84 525   - 1,0  4 857  5 318   - 4,9  39 811  68 265  108 076
# 1      2006  80 309   - 5,0  4 326  4 709     -15  40 662  61 463  102 125
# 2      2007  81 272   + 1,2  4 265  4 620   - 2,0  38 615  64 586  103 201
# 3      2008  74 487   - 8,3  3 933  4 275   - 7,5  36 179  58 833   93 798
# 4      2009  72 315   - 2,9  3 956  4 273   - 0,1  34 506  57 611   90 934
# 5      2010  67 288   - 7,0  3 706  3 992   - 6,6  30 393  54 068   84 461
# 6      2011  65 024   - 3,4  3 647  3 963   - 0,7  29 679  51 572   81 251
# 7      2012  60 437   - 6,9  3 386  3 653   - 8,0  27 142  48 709   75 851
# 8      2013  56 812   - 6,0  3 020  3 268  - 10,5  25 966  44 641   70 607
# 9      2014  58 191   + 2,4  3 146  3 384   + 3,5  26 635  46 413   73 048
# 10     2015  56 603   - 2,7  3 160  3 461   + 2,3  26 595  44 207   70 802
# ...

# %%
df3.columns = ['Année','Nombre des accidents','évolution en %','dont accidents mortels','Nombre','Évolution en %','Blessés graves','Blessés légers','Nombre des blessés','Évolution des blessés en %','Tués pour 100 accidents corporels']
#col_index="Année"
df3=df3.set_index('Année')
df3.head()
# Out:
#       Nombre des accidents évolution en % dont accidents mortels Nombre  \
# Année
# 2005                84 525          - 1,0                  4 857  5 318
# 2006                80 309          - 5,0                  4 326  4 709
# 2007                81 272          + 1,2                  4 265  4 620
# 2008                74 487          - 8,3                  3 933  4 275
# 2009                72 315          - 2,9                  3 956  4 273
#
#       Évolution en % Blessés graves Blessés légers Nombre des blessés  \
# Année
# 2005           - 4,9         39 811         68 265            108 076
# 2006             -15         40 662         61 463            102 125
# 2007           - 2,0         38 615         64 586            103 201
# 2008           - 7,5         36 179         58 833             93 798
# 2009           - 0,1         34 506         57 611             90 934
#
#       Évolution des blessés en %  Tués pour 100 accidents corporels
# Année
# ...

# %%
df3.rename(index = {'2019[5]': '2019','2020[5]':'2020' }, inplace = True)
df3.head(100)
# Out:
#       Nombre des accidents évolution en % dont accidents mortels Nombre  \
# Année
# 2005                84 525          - 1,0                  4 857  5 318
# 2006                80 309          - 5,0                  4 326  4 709
# 2007                81 272          + 1,2                  4 265  4 620
# 2008                74 487          - 8,3                  3 933  4 275
# 2009                72 315          - 2,9                  3 956  4 273
# 2010                67 288          - 7,0                  3 706  3 992
# 2011                65 024          - 3,4                  3 647  3 963
# 2012                60 437          - 6,9                  3 386  3 653
# 2013                56 812          - 6,0                  3 020  3 268
# 2014                58 191          + 2,4                  3 146  3 384
# 2015                56 603          - 2,7                  3 160  3 461
# 2016                57 522          + 1,6                    ---  3 477
# ...

# %%
frames = (df1, df2, df3)

data = pd.concat(frames)
data.head(100)
# Out:
#       Nombre des accidents évolution en % dont accidents mortels Nombre  \
# Année
# 1955               140 232         + 12,2                  7 554  8 058
# 1956               141 737          + 1,1                  7 740  8 283
# 1957               143 796          + 1,4                  8 055  8 517
# 1958               134 713          - 6,3                  7 520  8 126
# 1959               137 273          + 1,9                  7 847  8 409
# ...                    ...            ...                    ...    ...
# 2016                57 522          + 1,6                    ---  3 477
# 2017                58 613          + 1,9                    ---  3 448
# 2018                55 766          - 4,9                    ---  3 248
# 2019                56 016          + 0,4                    ---  3 244
# 2020                45 121         - 19,4                    ---  2 541
#
#       Évolution en % Blessés graves Blessés légers Nombre des blessés  \
# Année
# ...
